# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_data = pd.read_csv("encoded_data.csv")

# %%
raw_data
# Out:
#      Subdivision   Acres  Paved Street  Winter Access  Bedrooms  Total Baths  \
# 0             44  1.1490             0              1         3          3.0
# 1             28  0.2990             1              1         3          2.0
# 2             37  0.2500             0              1         2          1.0
# 3             84  0.5100             1              1         3          2.5
# 4             75  0.2800             1              1         3          2.0
# ..           ...     ...           ...            ...       ...          ...
# 174           88  0.5112             0              1         3          2.5
# 175           33  1.0168             0              1         1          1.0
# 176           44  1.9000             0              1         4          3.0
# 177            1  0.0000             1              1         2          1.0
# 178           26  0.2137             1              1         3          2.0
#
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Subdivision     179 non-null    int64
#  1   Acres           179 non-null    float64
#  2   Paved Street    179 non-null    int64
#  3   Winter Access   179 non-null    int64
#  4   Bedrooms        179 non-null    int64
#  5   Total Baths     179 non-null    float64
#  6   Apx Fin SqFt    179 non-null    int64
#  7   Age             179 non-null    int64
#  8   Garage          179 non-null    int64
#  9   Carport         179 non-null    int64
#  10  Foundation      179 non-null    int64
#  11  Heat            179 non-null    int64
#  12  Sewer           179 non-null    int64
#  13  Water           179 non-null    int64
#  14  Sold Price      179 non-null    float64
#  15  Days on Market  179 non-null    int64
#  16  City_Donnelly   179 non-null    bool
# ...

# %%
from sklearn.model_selection import train_test_split

x = raw_data.drop(['Sold Price'], axis=1)
y = raw_data['Sold Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2) #split the df into training 80% and test 20% sets

# %%
train_data = x_train.join(y_train)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 143 entries, 95 to 60
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Subdivision     143 non-null    int64
#  1   Acres           143 non-null    float64
#  2   Paved Street    143 non-null    int64
#  3   Winter Access   143 non-null    int64
#  4   Bedrooms        143 non-null    int64
#  5   Total Baths     143 non-null    float64
#  6   Apx Fin SqFt    143 non-null    int64
#  7   Age             143 non-null    int64
#  8   Garage          143 non-null    int64
#  9   Carport         143 non-null    int64
#  10  Foundation      143 non-null    int64
#  11  Heat            143 non-null    int64
#  12  Sewer           143 non-null    int64
#  13  Water           143 non-null    int64
#  14  Days on Market  143 non-null    int64
#  15  City_Donnelly   143 non-null    bool
#  16  City_McCall     143 non-null    bool
# ...

# %%
train_data.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'Subdivision'}>,
#         <Axes: title={'center': 'Acres'}>,
#         <Axes: title={'center': 'Paved Street'}>,
#         <Axes: title={'center': 'Winter Access'}>],
#        [<Axes: title={'center': 'Bedrooms'}>,
#         <Axes: title={'center': 'Total Baths'}>,
#         <Axes: title={'center': 'Apx Fin SqFt'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Garage'}>,
#         <Axes: title={'center': 'Carport'}>,
#         <Axes: title={'center': 'Foundation'}>,
#         <Axes: title={'center': 'Heat'}>],
#        [<Axes: title={'center': 'Sewer'}>,
#         <Axes: title={'center': 'Water'}>,
#         <Axes: title={'center': 'Days on Market'}>,
#         <Axes: title={'center': 'Closed Year'}>],
#        [<Axes: title={'center': 'Closed Month'}>,
#         <Axes: title={'center': 'Closed Day'}>,
#         <Axes: title={'center': 'Sold Price'}>, <Axes: >]], dtype=object)

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['Acres'] = np.log(train_data['Acres'] + 1)
train_data['Days on Market'] = np.log(train_data['Days on Market'] + 1)

# %%
train_data.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'Subdivision'}>,
#         <Axes: title={'center': 'Acres'}>,
#         <Axes: title={'center': 'Paved Street'}>,
#         <Axes: title={'center': 'Winter Access'}>],
#        [<Axes: title={'center': 'Bedrooms'}>,
#         <Axes: title={'center': 'Total Baths'}>,
#         <Axes: title={'center': 'Apx Fin SqFt'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Garage'}>,
#         <Axes: title={'center': 'Carport'}>,
#         <Axes: title={'center': 'Foundation'}>,
#         <Axes: title={'center': 'Heat'}>],
#        [<Axes: title={'center': 'Sewer'}>,
#         <Axes: title={'center': 'Water'}>,
#         <Axes: title={'center': 'Days on Market'}>,
#         <Axes: title={'center': 'Closed Year'}>],
#        [<Axes: title={'center': 'Closed Month'}>,
#         <Axes: title={'center': 'Closed Day'}>,
#         <Axes: title={'center': 'Sold Price'}>, <Axes: >]], dtype=object)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train, y_train = train_data.drop(['Sold Price'], axis=1), train_data['Sold Price']
x_train_s = scaler.fit_transform(x_train)
reg = LinearRegression()

reg.fit(x_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

# %%
x_test, y_test = test_data.drop(['Sold Price'], axis=1), test_data['Sold Price']

# %%
x_test_s = scaler.transform(x_test)

# %%
x_test
# Out:
#      Subdivision   Acres  Paved Street  Winter Access  Bedrooms  Total Baths  \
# 113           89  1.0300             1              1         3          2.0
# 105           74  0.3600             1              1         4          3.5
# 107           92  0.4810             0              1         3          2.0
# 93            16  4.1040             1              1         4          3.0
# 37            57  0.3090             0              1         5          3.0
# 91            26  0.2300             1              1         3          2.0
# 116            6  1.9670             1              1         3          3.0
# 150           93  0.4590             1              1         3          2.0
# 20             4  0.1480             1              1         3          3.0
# 129           79  0.0689             1              1         2          2.5
# 166           48  0.2200             1              1         3          2.0
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 113 to 21
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Subdivision     36 non-null     int64
#  1   Acres           36 non-null     float64
#  2   Paved Street    36 non-null     int64
#  3   Winter Access   36 non-null     int64
#  4   Bedrooms        36 non-null     int64
#  5   Total Baths     36 non-null     float64
#  6   Apx Fin SqFt    36 non-null     int64
#  7   Age             36 non-null     int64
#  8   Garage          36 non-null     int64
#  9   Carport         36 non-null     int64
#  10  Foundation      36 non-null     int64
#  11  Heat            36 non-null     int64
#  12  Sewer           36 non-null     int64
#  13  Water           36 non-null     int64
#  14  Days on Market  36 non-null     int64
#  15  City_Donnelly   36 non-null     bool
#  16  City_McCall     36 non-null     bool
# ...

# %%
reg.score(x_test_s, y_test) 
# this doesn't work because we used label encoding on some columns
# this means its weighting some
# Out:
# -3.389796937398219

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s, y_test)
# Out:
# 0.7005540262755124

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    'n_estimators' : [10, 20, 30],
    'max_features': [2, 4, 6],
}

grid_search = GridSearchCV(forest, param_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True)

grid_search.fit(x_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6],
#                          'n_estimators': [10, 20, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(x_test_s, y_test)
# Out:
# 0.5873667487155491
